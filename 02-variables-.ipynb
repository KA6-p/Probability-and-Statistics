# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
url = 'nhanes_2015_2016.csv'
da = pd.read_csv(url)

# %% [markdown]
# # Studying Discrete Values

# %%
gender = da['RIAGENDR']
gender.value_counts()
# Out:
# RIAGENDR
# 2    2976
# 1    2759
# Name: count, dtype: int64

# %%
gender.value_counts().plot(kind='bar')
plt.show()

# %%
gender.value_counts().plot(kind='bar')
plt.xticks([0,1],['Male','Female'])
plt.xlabel("Gender")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## Most Common Value

# %%
sizes = np.array([22,22,23,29,29,32,39,42,42,42,42,42,42,42,42,43,47,48,56,53,52,56,59,61,65,69,71,73,75,78,79,81,82,84,85,88,89,91,92,99])

# %%
sizes.mean()
# Out:
# np.float64(57.7)

# %%
from collections import Counter
cn = Counter()

for size in sizes:
    cn[size]+=1
cn.most_common()
# Out:
# [(np.int64(42), 8),
#  (np.int64(22), 2),
#  (np.int64(29), 2),
#  (np.int64(56), 2),
#  (np.int64(23), 1),
#  (np.int64(32), 1),
#  (np.int64(39), 1),
#  (np.int64(43), 1),
#  (np.int64(47), 1),
#  (np.int64(48), 1),
#  (np.int64(53), 1),
#  (np.int64(52), 1),
#  (np.int64(59), 1),
#  (np.int64(61), 1),
#  (np.int64(65), 1),
#  (np.int64(69), 1),
#  (np.int64(71), 1),
#  (np.int64(73), 1),
#  (np.int64(75), 1),
#  (np.int64(78), 1),
#  (np.int64(79), 1),
#  (np.int64(81), 1),
#  (np.int64(82), 1),
#  (np.int64(84), 1),
#  (np.int64(85), 1),
#  (np.int64(88), 1),
#  (np.int64(89), 1),
#  (np.int64(91), 1),
#  (np.int64(92), 1),
#  (np.int64(99), 1)]

# %%
# alternative library scipy
# !pip install scipy
# Out:
# Requirement already satisfied: scipy in c:\users\dell\onedrive\desktop\gitdemo\venv\lib\site-packages (1.16.0)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in c:\users\dell\onedrive\desktop\gitdemo\venv\lib\site-packages (from scipy) (2.3.1)
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from scipy import stats
stats.mode(sizes)
# Out:
# ModeResult(mode=np.int64(42), count=np.int64(8))

# %%
gender.mode()
# Out:
# 0    2
# Name: RIAGENDR, dtype: int64

# %%
stats.mode(gender)
# Out:
# ModeResult(mode=np.int64(2), count=np.int64(2976))

# %% [markdown]
# ## More than One "Classes"

# %%
da['HIQ210'].unique()
# Out:
# array([ 2., nan,  1.,  9.])

# %%
da['HIQ210'].value_counts().plot(kind = 'bar')
plt.show()

# %%
da['HIQ210'].value_counts().plot(kind = 'pie') # highly NOT recommended!
plt.show()

# %% [markdown]
# # Studying Real Valued Numbers

# %%
wt = da['BMXWT']
wt.value_counts().plot(kind = 'bar')
plt.show()

# %%
wt.hist(bins=20)
plt.plot()
# Out:
# []

# %% [markdown]
# ### Custom Matplotlib Histogram

# %%
plt.hist(wt,bins=20)
plt.xlabel("Weights")
plt.ylabel("Frequency")
plt.title("Histogram of Weights in NHANES Dataset")
plt.show()

# %% [markdown]
# ### Prettifying and Styling Matplotlib with Seaborn

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\dell\onedrive\desktop\gitdemo\venv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\dell\onedrive\desktop\gitdemo\venv\lib\site-packages (from seaborn) (2.3.1)
# Requirement already satisfied: pandas>=1.2 in c:\users\dell\onedrive\desktop\gitdemo\venv\lib\site-packages (from seaborn) (2.3.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\dell\onedrive\desktop\gitdemo\venv\lib\site-packages (from seaborn) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\onedrive\desktop\gitdemo\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\onedrive\desktop\gitdemo\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\onedrive\desktop\gitdemo\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dell\onedrive\desktop\gitdemo\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\onedrive\desktop\gitdemo\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\dell\onedrive\desktop\gitdemo\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dell\onedrive\desktop\gitdemo\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\onedrive\desktop\gitdemo\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\onedrive\desktop\gitdemo\venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\onedrive\desktop\gitdemo\venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\dell\onedrive\desktop\gitdemo\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
sns.set(color_codes=True)
sns.set_style("white")

# %%
sns.displot(wt,bins=20)
plt.xlabel("Weights")
plt.ylabel("Frequency")
plt.title("Histogram of Weights in NHANES Dataset")
sns.despine(offset=5,trim=True);
plt.show()

# %% [markdown]
# ### Studying Central Tendency

# %%
plt.figure(figsize=(20,5))

x= range(da['BMXWT'].size)
y = da['BMXWT']

plt.scatter(x,y,marker = 'x',s=0.5)

plt.title("Weights of Individuals")
plt.xlabel("ID of Individuals")
plt.ylabel("Weight (kg)")

# plot the estimate line
p1=(0,75)
p2=(6000,75)
x_c,y_c = zip(p1,p2)
plt.plot(x_c,y_c,color='red',linewidth=0.75)

plt.show()

# %%
wt.mean()
# Out:
# np.float64(81.34267560889516)

# %%
plt.figure(figsize=(20,5))

x= range(da['BMXWT'].size)
y = da['BMXWT']

plt.scatter(x,y,marker = 'x',s=0.5)

plt.title("Weights of Individuals")
plt.xlabel("ID of Individuals")
plt.ylabel("Weight (kg)")

# plot the estimate line
p1=(0,75)
p2=(6000,75)
x_c,y_c = zip(p1,p2)
plt.plot(x_c,y_c,color='red',linewidth=0.75)

x_c,y_c = ([0,6000],[wt.mean(),wt.mean()])
plt.plot(x_c,y_c,color='green',linewidth=0.75)
plt.show()

# %% [markdown]
# ### Problem with Arithmetic Mean

# %%
import numpy as np

# %%
nums = np.array([3,4,9,17,18,20,22,23,29,32,39,42,42,42,51,97])

# %%
np.mean(nums)
# Out:
# np.float64(30.625)

# %%
np.median(nums)
# Out:
# np.float64(26.0)

# %% [markdown]
# # Visualizing Weights Data
# #### The problem with our weights data is similar

# %%
wt.max()
# Out:
# np.float64(198.9)

# %%
wt.min()
# Out:
# np.float64(32.4)

# %%
wt.median()
# Out:
# np.float64(78.2)

# %%
plt.figure(figsize=(20,5))
x= range(da['BMXWT'].size)
y = da['BMXWT']

plt.scatter(x,y,marker = 'x',s=0.5)

plt.title("Weights of Individuals")
plt.xlabel("ID of Individuals")
plt.ylabel("Weight (kg)")

# plot the estimate line
x_c,y_c = ([0,6000],[wt.median(),wt.median()])
plt.plot(x_c,y_c,color='red',linewidth=0.75)


x_c,y_c = ([0,6000],[wt.mean(),wt.mean()])
plt.plot(x_c,y_c,color='green',linewidth=0.75)
plt.show()

# %% [markdown]
# ## Quartiles and Boxplots

# %%
nums = np.array([3,4,9,17,18,20,22,23,29,32,39,42,42,42,51,97])

# %%
np.median(nums)
# Out:
# np.float64(26.0)

# %%
import statistics

# %%
statistics.quantiles(nums,n=4)
# Out:
# [np.float64(17.25), np.float64(26.0), np.float64(42.0)]

# %%
statistics.quantiles(wt,n=4)
# Out:
# [43.7, 50.8, 50.1]

# %%
ax = sns.boxplot(x=wt)

# %%
male_wt = da.loc[da['RIAGENDR'] == 2, 'BMXWT']
male_wt.mean()
# Out:
# np.float64(76.51676280963693)

# %%
female_wt = da.loc[da['RIAGENDR'] == 1, 'BMXWT']
female_wt.mean()
# Out:
# np.float64(86.57326222876058)

# %%
# But there is an easier way
plt.figure(figsize=(4,8))
sns.set_style("whitegrid")

ax = sns.boxplot(  x='RIAGENDR',y='BMXWT',        data = da)

# %%
plt.figure(figsize=(4,8))
sns.set_style("whitegrid")

ax = sns.boxplot(  x='HIQ210',y='BMXWT',        data = da)
